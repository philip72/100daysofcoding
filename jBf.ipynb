# %%
# !pip install bs4

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
URL="https://www.jumia.co.ke/phones-tablets/"
HEADERS= ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36','Accept-LAnguage':'en-US, en;q=0.5'})

# %%
webpage=requests.get(URL, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
webpage.content
# Out:
# b'<!DOCTYPE html><html lang="en" dir="ltr"><head><meta charset="utf-8" /><title>Phones and Tablets - Buy Phones and Tablets Online | Jumia Kenya</title><meta property="og:type" content="product" /><meta property="og:site_name" content="Jumia Kenya" /><meta property="og:title" content="Phones and Tablets - Buy Phones and Tablets Online | Jumia Kenya" /><meta property="og:description" content="Buy Phones and Tablets online at Jumia Kenya. Jumia offers massive discount on the latest smartphones and tablets. Check out the latest smartphones &amp; tablets. Enjoy great prices with Jumia.  Order now and pay on delivery. " /><meta property="og:url" content="/phones-tablets/" /><meta property="og:image" content="https://ke.jumia.is/cms/icons/jumialogo-x-4.png" /><meta property="og:locale" content="en_KE" /><meta name="title" content="Phones and Tablets - Buy Phones and Tablets Online | Jumia Kenya" /><meta name="robots" content="index,follow " /><meta name="description" content="Buy Phones an
# ...

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links= soup.find_all("a", attrs={'class':'core'})
links
# Out:
# [<a class="core" data-brand="XIAOMI" data-category="Phones &amp; Tablets/Mobile Phones/Smartphones/Android Phones" data-dimension23="5815" data-dimension26="" data-dimension27="" data-dimension28="1" data-dimension37="0" data-dimension43="BF22|COL_216|COL_306|COL_307|COL_308|COL_317|CP_2|CP_UN91|DOD_2|JMALL|UND_50" data-dimension44="0" data-id="XI996MP11A2S4NAFAMZ" data-list="productfloor_1_category:Phones_&amp;_Tablets_8070_en_KE" data-name='Redmi 10A, 6.53", 3GB+64GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Graphite Grey' data-position="1" data-price="102.37" data-track-onclick="eecProduct" data-track-onview="eecProduct" href="/xiaomi-redmi-10a-6.53-3gb64gb-13.0mp-5000mah-4g-lte-dual-sim-graphite-grey-65951626.html"><img alt='XIAOMI Redmi 10A, 6.53", 3GB+64GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Graphite Grey' class="img" data-lazy="" data-src="https://ke.jumia.is/unsafe/fit-in/300x300/filters:fill(white)/product/62/615956/1.jpg?0358" height="185" src="..." width="185"/><div class="nam
# ...

# %%
link=links[0].get('href')
link
# Out:
# '/xiaomi-redmi-10a-6.53-3gb64gb-13.0mp-5000mah-4g-lte-dual-sim-graphite-grey-65951626.html'

# %%
jumi_link="https://jumia.co.ke"

# %%
product_list= jumi_link+link

# %%
product_list
# Out:
# 'https://jumia.co.ke/xiaomi-redmi-10a-6.53-3gb64gb-13.0mp-5000mah-4g-lte-dual-sim-graphite-grey-65951626.html'

# %%
new_webpage=requests.get(product_list, headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
new_soup = BeautifulSoup(new_webpage.content, "html.parser")
new_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_title= new_soup.find("h1", attrs={'class':"-fs20 -pts -pbxs"}).text.strip()
product_title
# Out:
# 'XIAOMI Redmi 10A, 6.53", 3GB+64GB, 13.0MP, 5000mAh, 4G LTE, Dual SIM - Graphite Grey'

# %%
product_price= new_soup.find("span", attrs={'class':"-b -ltr -tal -fs24"}).text.strip()

# %%
product_price
# Out:
# 'KSh 12,999'

# %%
product_rating= new_soup.find("div", attrs={'class':"stars _s _al"}).text
product_rating
# Out:
# '4.2 out of 5'
